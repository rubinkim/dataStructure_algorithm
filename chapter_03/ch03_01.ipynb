# %% [markdown]
# ##### 자료구조의 개념과 종류

# %%
# 자료구조란 "컴퓨터 프로그래밍 언어에서 효율적인 자료(데이터)의 형태"를 의미한다. 자료를 찾을 때 훨씬 빠르고 효율적인
# 결과가 나올 수 있도록 해준다. 즉 데이터는 동일하지만 효율적인 자료구조에 저장함으로써 관리도 효율적이게 된다.
# 단순 자료구조 : 정수, 실수, 문자, 문자열
# 선형 자료구조 : 선형리스트, 연결리스트, 스택, 큐
# 비선형 자료구조 : 트리, 그래프
# 파일 자료구조 : 순차파일, 색인파일, 직접파일

# %%
# 알고리즘이란 "어떤 문제를 해결해 가는 논리적인 과정"으로 정의할 수 있다.
# 자료구조와 알고리즘의 관계는 "자료구조를 자동차 부품이라고 하면 자동차를 완성하기 위해 이 부품들을 조립하는 방법
# 은 알고리즘"으로 생각할 수 있다. 이런 알고리즘으로 실제 자동차 조립은 프로그래밍 언어를 사용해서 진행하고 완성된
# 자동차는 소프트웨어(프로그램)로 생각하면 된다.
# 우리는 자료구조와 알고리즘을 익히고 파이썬 언어를 이용해서 최종적인 소프트웨어를 완성하는 과정을 배운다
